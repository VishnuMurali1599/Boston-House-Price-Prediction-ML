# %% [markdown]
# ## Data Ingestion and Data Understanding

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\BostonHousing.csv")

# %%
df.shape
# Out:
# (506, 14)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.rename(columns={'medv':'Price'},inplace=True)

# %%
## Renaming MEDV column to Price 
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
## Data types of all coulmns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## Checking Missing Values
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# Price      0
# dtype: int64

# %%
## Summarizing the Stats of the Data
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
## Missing some values in RM column
## rm: Average number of rooms per dwelling
df['rm'].value_counts()
# Out:
# 6.405    3
# 6.229    3
# 6.167    3
# 5.713    3
# 6.127    3
#         ..
# 6.020    1
# 6.546    1
# 5.859    1
# 6.416    1
# 6.976    1
# Name: rm, Length: 441, dtype: int64

# %%
df['rm'].unique()
# Out:
# array([6.575, 6.421, 7.185, 6.998, 7.147, 6.43 , 6.012, 6.172, 5.631,
#        6.004,   nan, 6.009, 5.889, 5.949, 6.096, 5.834, 5.935, 5.99 ,
#        5.456, 5.727, 5.57 , 5.965, 6.142, 5.813, 5.924, 5.599, 6.047,
#        6.495, 6.674, 5.713, 6.072, 5.95 , 5.701, 5.841, 5.85 , 5.966,
#        6.595, 7.024, 6.77 , 6.169, 6.211, 6.069, 5.682, 5.786, 6.03 ,
#        5.399, 5.602, 5.963, 6.115, 6.511, 5.998, 5.888, 7.249, 6.383,
#        6.816, 6.145, 5.927, 5.741, 6.456, 7.104, 6.29 , 5.787, 5.878,
#        5.594, 5.885, 6.417, 5.961, 6.065, 6.245, 6.273, 6.286, 6.279,
#        6.14 , 6.232, 5.874, 6.727, 6.619, 6.302, 6.167, 6.389, 6.63 ,
#        6.015, 6.121, 7.007, 7.079, 6.405, 6.442, 6.249, 6.625, 8.069,
#        7.82 , 7.416, 6.781, 6.137, 5.851, 5.836, 6.127, 6.474, 6.229,
#        6.195, 6.715, 5.913, 6.092, 6.254, 5.928, 6.176, 6.021, 5.872,
#        5.731, 5.87 , 5.856, 5.879, 5.986, 5.613, 5.693, 6.431, 5.637,
# ...

# %%
df['rm'].mean()
# Out:
# 6.28434131736527

# %%
## Imputing Missing value with mean value
df.fillna(value=df['rm'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# Price      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### Correlation
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219261  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.310847 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.392052  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091434  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302051  0.731470
# rm      -0.219261  0.310847 -0.392052  0.091434 -0.302051  1.000000 -0.239632
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.239632  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.202268 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210353  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292178  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356065  0.261515
# ...

# %%
sns.pairplot(df)

# %%
plt.scatter(df['crim'],y=df['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df['rm'],y=df['Price'])
plt.xlabel("rm")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x=df['rm'],y=df['Price'],data=df)
# Out:
# <Axes: xlabel='rm', ylabel='Price'>

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'Price'],
#       dtype='object')

# %%
plt.scatter(df['lstat'],y=df['Price'])
plt.xlabel("lstat")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x=df['ptratio'],y=df['Price'])
# Out:
# <Axes: xlabel='ptratio', ylabel='Price'>

# %% [markdown]
# ### Preparing Independent and Dependent Features

# %%
X=df.iloc[:,:-1]
X.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y=df.iloc[:,-1:]
y.head()
# Out:
#    Price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4
# 4   36.2

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#          crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 5     0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158  0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142  0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393  0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570  0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
#
#      ptratio       b  lstat
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13

# %%
y_train.head()
# Out:
#      Price
# 5     28.7
# 116   21.2
# 45    19.3
# 16    23.1
# 468   19.1

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354, 1)
# (152, 1)

# %% [markdown]
# ### Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[-1.10823836,  0.81189823,  0.35257783,  0.81518768, -1.79607311,
#          2.90447276, -0.29378061, -2.93049502,  2.09664195, -1.44672618,
#         -2.05845103,  1.02339256, -3.88893987]])

# %%
lr.intercept_
# Out:
# array([23.01581921])

# %% [markdown]
# ### Prediction of the model

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([[28.63252461],
#        [36.48602086],
#        [15.4189334 ],
#        [25.39319615],
#        [18.85542687],
#        [23.14196315],
#        [17.38803819],
#        [14.06783335],
#        [23.04060004],
#        [20.58567038],
#        [24.8304966 ],
#        [18.54903944],
#        [-6.85534914],
#        [21.79886221],
#        [19.22195173],
#        [26.18174676],
#        [20.2844755 ],
#        [ 5.62300497],
#        [40.43768792],
#        [17.57865999],
#        [27.42731845],
#        [30.15917866],
#        [10.93074566],
#        [23.99706963],
#        [18.07925258],
#        [15.94318816],
#        [23.12256494],
#        [14.55801939],
#        [22.33614573],
#        [19.31522404],
#        [22.15661595],
#        [25.17988256],
#        [25.29889979],
#        [18.5274093 ],
#        [16.62345866],
#        [17.52123633],
#        [30.9352234 ],
#        [20.18058657],
#        [23.9016633 ],
#        [24.85660195],
#        [13.92840266],
# ...

# %%
## On which parameters model have trained
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %% [markdown]
# ### Plotting Scatter for prediction

# %%
plt.scatter(y_test,y_pred)

# %%
## Prediction with Residuls
Residual=y_test-y_pred

# %%
Residual
# Out:
#          Price
# 173  -5.032525
# 274  -4.086021
# 491  -1.818933
# 72   -2.593196
# 452  -2.755427
# ..         ...
# 441  -0.301415
# 23    1.123598
# 225  10.053915
# 433  -2.382093
# 447  -5.687081
#
# [152 rows x 1 columns]

# %%
## PLotting the Residual
sns.displot(Residual,kind='kde')

# %%
### Prediction and Residulas
### Uniform distribution
plt.scatter(y_pred,Residual)

# %%
import numpy as np

# %%
## Performance Metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 3.1739886727549296
# 21.598288672542026
# 4.647395902281408

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
## Adjusted r2 score
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6828354816140237

# %% [markdown]
# ## New Data Prediction

# %%
X.values[1].reshape(1,-1)
# Out:
# array([[2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9690e+02, 9.1400e+00]])

# %%
### Apply standardization

# %%
scaler.transform(X.values[2].reshape(1,-1))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41456707, -0.50512499, -0.58639669, -0.28154625, -0.75676687,
#          1.1957949 , -0.27871012,  0.5658082 , -0.862084  , -0.99251596,
#         -0.21208981,  0.38165277, -1.18145831]])

# %%
lr.predict(scaler.transform(X.values[2].reshape(1,-1)))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[30.9352234]])

# %% [markdown]
# ## Pickiling The Model file for Deployment

# %%
import pickle

# %%
pickle.dump(lr,open('regression.pkl','wb'))

# %%
cd
# Out:
# C:\Users\DELL

# %%
pickled_model=pickle.load(open('regression.pkl','rb'))

# %%
pickled_model.predict(scaler.transform(X.values[2].reshape(1,-1)))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[30.9352234]])

# %%
pickled_model.predict(scaler.transform(X.values[10].reshape(1,-1)))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[18.15959882]])

# %%
pickled_model.predict(scaler.transform(X.values[20].reshape(1,-1)))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[11.95255304]])
